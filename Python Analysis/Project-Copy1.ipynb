# %%
import pandas as pd
import datetime

# %% [markdown]
# # Preparing dataframes for analysis

# %%
df = pd.read_csv("crossword_year_2022.csv")
df.drop('Unnamed: 0', inplace=True, axis=1)
df
# Out:
#       crossword_date  answers                              clues  \
# 0         2022-01-01   WINNER                      First person?
# 1         2022-01-01   PLANBS                            Backups
# 2         2022-01-01   WHOOPI         First name in daytime talk
# 3         2022-01-01  MAOSUIT                 Red Guard's attire
# 4         2022-01-01   IAMBIC          Like "To be or not to be"
# ...              ...      ...                                ...
# 15765     2022-07-08    STOAT                 Source of some fur
# 15766     2022-07-08     KONA                 Hawaii's ___ Coast
# 15767     2022-07-08     FELL                           Cut down
# 15768     2022-07-08     ERRS                        Isn't right
# 15769     2022-07-08      DEI  ___ Fratelli (tomato sauce brand)
#
#        crossword_year
# 0                2022
# 1                2022
# 2                2022
# 3                2022
# 4                2022
# ...               ...
# 15765            2022
# 15766            2022
# 15767            2022
# 15768            2022
# 15769            2022
#
# [15770 rows x 4 columns]

# %%
df2 = pd.read_csv("slangtill2015.csv")
df2.drop('Unnamed: 0', inplace = True, axis =1)
df3 = df2.append(df, ignore_index=True)
df3
# Out:
# C:\Users\aisvarya\AppData\Local\Temp\ipykernel_72680\1600407043.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df2.append(df, ignore_index=True)
#         crossword_date answers                              clues  \
# 0           1976-01-05    AJAX                         Greek hero
# 1           1976-01-05   WHOOP                           Loud cry
# 2           1976-01-05    CRAB                     Peevish person
# 3           1976-01-05    BALI                      Romantic isle
# 4           1976-01-05   HEAVE                               Lift
# ...                ...     ...                                ...
# 1243277     2022-07-08   STOAT                 Source of some fur
# 1243278     2022-07-08    KONA                 Hawaii's ___ Coast
# 1243279     2022-07-08    FELL                           Cut down
# 1243280     2022-07-08    ERRS                        Isn't right
# 1243281     2022-07-08     DEI  ___ Fratelli (tomato sauce brand)
#
#          crossword_year
# 0                  1976
# 1                  1976
# 2                  1976
# 3                  1976
# 4                  1976
# ...                 ...
# 1243277            2022
# 1243278            2022
# 1243279            2022
# 1243280            2022
# 1243281            2022
#
# [1243282 rows x 4 columns]

# %% [markdown]
# ### df_answers_clues is a dataframe with XW puzzle data from 1976 - 2022 (June)
# To reduce the load/scrape time, I only included three columns: answers, clues and crossword date. But several other attributes are available for analysis

# %%
df_2018 = pd.read_csv("crossword_year_2018_2022 - crossword_year_2018_2022.csv")
df_2018.drop('Unnamed: 0', inplace=True, axis=1)
df_answers_clues = df_2018.append(df3, ignore_index=True)
df_answers_clues = df_answers_clues.sort_values('crossword_year').drop_duplicates()
df_answers_clues
# Out:
# C:\Users\aisvarya\AppData\Local\Temp\ipykernel_72680\3772553669.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_answers_clues = df_2018.append(df3, ignore_index=True)
#         crossword_date         answers                              clues  \
# 237137      1976-10-16         EASTEND                     Part of a city
# 233337      1976-09-02           OMANI                      Muscat native
# 233336      1976-09-02             ARS                        ___ poetica
# 233335      1976-09-02           ICAME                  What "veni" means
# 233334      1976-09-02           SAWIN                Greeted at the door
# ...                ...             ...                                ...
# 1445147     2022-03-04             KAT                        Kit ___ bar
# 1445148     2022-03-05            MOSS         Much of Iceland's greenery
# 1445149     2022-03-05         PROVEIT              "I don't believe you"
# 1445151     2022-03-05  FRIENDLYBANTER                   Needle exchange?
# 1455655     2022-07-08             DEI  ___ Fratelli (tomato sauce brand)
#
#          crossword_year
# 237137             1976
# 233337             1976
# 233336             1976
# 233335             1976
# 233334             1976
# ...                 ...
# 1445147            2022
# 1445148            2022
# 1445149            2022
# 1445151            2022
# 1455655            2022
#
# [1455643 rows x 4 columns]

# %% [markdown]
# ### Slang is a dataframe that I created with most of the words NYT editors considered slang.
#
# Modifiers in the clue that I used to collect these words are:
# colloquially, modern lingo, slang, informally, slangily, in texts

# %%
slang = df_answers_clues[df_answers_clues['clues'].str.contains('in texts', regex=False) |df_answers_clues['clues'].str.contains('colloquially', regex=False) |df_answers_clues['clues'].str.contains('modern lingo', regex=False) | df_answers_clues['clues'].str.contains('slang', regex=False) | df_answers_clues['clues'].str.contains('informally', regex=False) | df_answers_clues['clues'].str.contains('slangily', regex=False)]
slang
# Out:
#         crossword_date answers                                        clues  \
# 252416      1977-04-10   LEGGO                          68 Across, slangily
# 284758      1978-04-21   SCHMO                            Sap, in slanguage
# 286369      1978-05-09    OKAY                    Concurrence, colloquially
# 281906      1978-03-19  LIBBER                       Feminist, colloquially
# 320085      1979-09-02     ERK                 R.A.F. underling, informally
# ...                ...     ...                                          ...
# 1444957     2022-03-02     DJS                     Club workers, informally
# 1445043     2022-03-03    SESH                          Meeting, informally
# 1444857     2022-03-01   ALUMS                Reunion attendees, informally
# 1444908     2022-03-01     BRB                    "Hang on a sec," in texts
# 1445141     2022-03-04    ALTS  Secondary social media accounts, informally
#
#          crossword_year
# 252416             1977
# 284758             1978
# 286369             1978
# 281906             1978
# 320085             1979
# ...                 ...
# 1444957            2022
# 1445043            2022
# 1444857            2022
# 1444908            2022
# 1445141            2022
#
# [5461 rows x 4 columns]

# %% [markdown]
# <b> Tracking the lineage of a term's definition by looking at XWord Clues across time </b>

# %%
frequent_answers = df_answers_clues[df_answers_clues['answers'] == 'UNPACK']
frequent_answers
# Out:
#         crossword_date answers                                         clues  \
# 1004607     2001-10-07  UNPACK                   What to do after a vacation
# 1042191     2003-01-04  UNPACK                                   Empty boxes
# 162783      2020-05-15  UNPACK                     Work through, as feelings
# 189727      2021-04-04  UNPACK          Emotionally process, in modern lingo
# 192124      2021-05-02  UNPACK            Take care of some personal baggage
# 1451093     2022-05-15  UNPACK  Attempt to grasp, as a complicated situation
#
#          crossword_year
# 1004607            2001
# 1042191            2003
# 162783             2020
# 189727             2021
# 192124             2021
# 1451093            2022

# %% [markdown]
# <b> How modern is Shortz's modern slang? </b>
# <br/> Looking at the answers (slang terms) that he described as modern

# %%
slang = df_answers_clues[df_answers_clues['clues'].str.contains('modern lingo', regex=False) | df_answers_clues['clues'].str.contains('modern slang', regex=False)]
slang.to_csv("modern_slang.csv")

# %%
df_answers_clues[df_answers_clues['clues'].str.contains('', regex=False, na=False)]
# Out:
#         crossword_date         answers  \
# 1118674     2005-07-10  DININGALACRATE
#
#                                                  clues  crossword_year
# 1118674   Supper at home before unpacking from a move?            2005
